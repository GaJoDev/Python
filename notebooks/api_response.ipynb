# %%
import requests
import json

url = requests.get('https://api.coinpaprika.com/v1/tickers')

print(url.json())
# this was used just to demonstrate that the json is being returned

# data = url.json()
# This prints out the first record in data list index
# print(data[0])
# print(type(data))

# for testing, this just prints out the first record
# print(data[0])

# this converts the data variable from a list to a string
# list_to_string = str(data)
# print(list_to_string[0:5])
# print(type(list_to_string))

# Found this on stack overflow:
# https://stackoverflow.com/questions/77827572/converting-json-list-from-an-api-into-a-python-dictionary
# json_data = json.dumps(list_to_string)

# json_data = requests.get(url).json()

# print("json_data is the current class: ", type(json_data))

# key_list = list(json_data.keys())

# position = key_list.index(0, 5)
# print(key_list[position])
# # for id in range (1, 30):
# #     # print(id, ":", json_data[0])
# #     print(json_data[3:29])
# Out:
# [{'id': 'btc-bitcoin', 'name': 'Bitcoin', 'symbol': 'BTC', 'rank': 1, 'total_supply': 19790509, 'max_supply': 21000000, 'beta_value': 0.959796, 'first_data_at': '2010-07-17T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'price': 95590.898640893, 'volume_24h': 108539555275.73961, 'volume_24h_change_24h': 103.05, 'market_cap': 1891792539871, 'market_cap_change_24h': -1.91, 'percent_change_15m': -0.03, 'percent_change_30m': -0.26, 'percent_change_1h': -0.35, 'percent_change_6h': -0.12, 'percent_change_12h': -0.06, 'percent_change_24h': -1.91, 'percent_change_7d': 1, 'percent_change_30d': 39.51, 'percent_change_1y': 128.59, 'ath_price': 99649.56804294256, 'ath_date': '2024-11-22T19:39:21Z', 'percent_from_price_ath': -4.06}}}, {'id': 'eth-ethereum', 'name': 'Ethereum', 'symbol': 'ETH', 'rank': 2, 'total_supply': 120232214, 'max_supply': 0, 'beta_value': 1.11766, 'first_data_at': '2015-08-07T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'price': 3633.13971486881, 'volume_24h': 44504421453.31658, 'volume_24h_change_24h': 68.94, 'market_cap': 437525631375, 'market_cap_change_24h': -2.1, 'percent_change_15m': 0.08, 'percent_change_30m': -0.47, 'percent_change_1h': -0.32, 'percent_change_6h': 0.72, 'percent_change_12h': 0.29, 'percent_change_24h': -2.1, 'percent_change_7d': 5.28, 'percent_change_30d': 48.52, 'percent_change_1y': 61.59, 'ath_price': 4864.113196614236, 'ath_date': '2021-11-10T16:05:00Z', 'percent_from_price_ath': -25.32}}}, {'id': 'xrp-xrp', 'name': 'XRP', 'symbol': 'XRP', 'rank': 3, 'total_supply': 99986947886, 'max_supply': 100000000000, 'beta_value': 0.953263, 'first_data_at': '2013-08-04T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'price': 2.727979919756636, 'volume_24h': 42307216986.59937, 'volume_24h_change_24h': 97.95, 'market_cap': 155635322078, 'market_cap_change_24h': 15.25, 'percent_change_15m': 0.43, 'percent_change_30m': -0.07, 'percent_change_1h': 1.21, 'percent_change_6h': -0.46, 'percent_change_12h': 12.47, 'percent_change_24h': 15.25, 'percent_change_7d': 88.07, 'percent_change_30d': 435.07, 'percent_change_1y': 329.19, 'ath_price': 3.84194, 'ath_date': '2018-01-04T07:14:00Z', 'percent_from_price_ath': -29.2}}}, {'id': 'usdt-tether', 'name': 'Tether', 'symbol': 'USDT', 'rank': 4, 'total_supply': 139992368035, 'max_supply': 0, 'beta_value': -0.000462236, 'first_data_at': '2015-02-25T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'price': 1.0000395182539772, 'volume_24h': 254262349971.12457, 'volume_24h_change_24h': 135.84, 'market_cap': 134663351105, 'market_cap_change_24h': 0.44, 'percent_change_15m': 0.06, 'percent_change_30m': 0.02, 'percent_change_1h': -0.01, 'percent_change_6h': 0.06, 'percent_change_12h': 0.01, 'percent_change_24h': 0.04, 'percent_change_7d': 0.01, 'percent_change_30d': -0.02, 'percent_change_1y': 0, 'ath_price': 1.21549, 'ath_date': '2015-02-25T17:04:00Z', 'percent_from_price_ath': -17.73}}}, {'id': 'sol-solana', 'name': 'Solana', 'symbol': 'SOL', 'rank': 5, 'total_supply': 588682058, 'max_supply': 0, 'beta_value': 1.26631, 'first_data_at': '2020-08-26T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'price': 225.21990491246729, 'volume_24h': 13033666551.244717, 'volume_24h_change_24h': 192.29, 'market_cap': 107038936311, 'market_cap_change_24h': -4.02, 'percent_change_15m': 0.07, 'percent_change_30m': -0.25, 'percent_change_1h': -0.44, 'percent_change_6h': 0.79, 'percent_change_12h': -0.12, 'percent_change_24h': -4.04, 'percent_change_7d': -5.85, 'percent_change_30d': 39.71, 'percent_change_1y': 263.98, 'ath_price': 263.5633588232028, 'ath_date': '2024-11-22T03:21:20Z', 'percent_from_price_ath': -14.65}}}, {'id': 'bnb-binance-coin', 'name': 'Binance Coin', 'symbol': 'BNB', 'rank': 6, 'total_supply': 148930232, 'max_supply': 200000000, 'beta_value': 0.805365, 'first_data_at': '2017-07-25T00:00:00Z', 'last_updated': '2024-12-03T01:43:36Z', 'quotes': {'USD': {'pric ...
